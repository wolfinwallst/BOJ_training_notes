# %%
# 2562 최댓값_1D 배열
import sys
input = sys.stdin.readline

arr = []
for _ in range(9):
    arr.append(int(input()))

Max = max(arr)
for i in range(9):
    if arr[i] == Max:
        print(Max)
        print(i+1)
        break

# # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # 
# 2562 최댓값_1D 배열
import sys
input = sys.stdin.readline

arr = []
for _ in range(9):
    arr.append(int(input()))

""" 위 3 줄을 리스트 컴프리헨션으로 1줄로 바꿀 수 있다.
arr = [int(input()) for _ in range(9)]
"""

print(max(arr))
print(arr.index(max(arr)) + 1)
# # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # 
# 2562 최댓값_1D 배열
import sys
input = sys.stdin.readline

Max = 0
for i in range(1, 10):
    n = int(input())
    if n > Max:
        Max = n
        idx = i
print(Max)
print(idx)
# # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # 
# 2562 최댓값_1D 배열
import sys
input = sys.stdin.readline

Max = 0
for i in range(1, 10):
    n = int(input())
    if n > Max:
        Max = n
        idx = i
print("{} \n {}".format(Max, idx))
# print("%d\n%d" %(Max, idx)) # 대체 가능
# # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # #
