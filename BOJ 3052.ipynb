# %%
# 3052 나머지_1D 배열
import sys
input = sys.stdin.readline

cnt = 0
residue = [0 for _ in range(42)]
# residue = [0] * 42
for _ in range(10):
    n = int(input())
    if residue[n % 42] == 0:
        residue[n % 42] += 1
        cnt += 1

print(cnt)
# # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # 
# 3052 나머지_1D 배열
import sys
input = sys.stdin.readline

cnt = 0
residue = [0 for _ in range(42)]
for _ in range(10):
    n = int(input()) % 42 # n을 42로 나눈 나머지로 정의
    if residue[n] == 0:
        residue[n] += 1
        cnt += 1

print(cnt)
# # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # 
# 3052 나머지_1D 배열
import sys
input = sys.stdin.readline

residue = []
for _ in range(10):
    residue.append(int(input()) % 42)

residue = set(residue)
print(len(residue))
# # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # 
# 3052 나머지_1D 배열
import sys
input = sys.stdin.readline

residue = set()
for _ in range(10):
    residue.add(int(input()) % 42) # set의 add는 list의 append처럼 추가

print(len(residue))
# # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # 
# 3052 나머지_1D 배열
import sys
input = sys.stdin.readline

residue = [int(input()) % 42 for _ in range(10)]
print(len(set(residue)))
# # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # 
# 3052 나머지_1D 배열
import sys
input = sys.stdin.readline

num = []
for _ in range(10):
    num.append(int(input()))

residue = []
for j in num:
    r = j % 42
    if r in residue:
        pass
    else:
        residue.append(r)

print(len(residue))
# # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # 
# 3052 나머지_1D 배열
import sys
input = sys.stdin.readline

residue = []
for _ in range(10):
    n = int(input()) % 42
    if n not in residue:
        residue.append(n)
        
print(len(residue))
